# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.4.2'

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 42.7 MB 69.6 MB/s eta 0:00:01     |█████████████████████████       | 33.5 MB 69.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# 既可以运行代码，也可以写markdown。按m键切换（或者运行按键右边的按键切换）。按y切换为写代码

# %% [markdown]
# pyarrow库，解析pqrquet格式依赖库。parquet格式，列式存储数据

# %%
df=pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-01.parquet')

# %% [markdown]
# parquet格式便于用于存储，dataframe格式便于用于操作

# %%
df.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
import sklearn

# %%
sklearn.__version__
# Out:
# '1.0.2'

# %%
df1=pd.read_parquet('https://d37ci6vzurychx.cloudfront.net/trip-data/yellow_tripdata_2024-07.parquet')

# %%
df1.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2024-07-01 00:34:56   2024-07-01 00:46:49              1.0
# 1         2  2024-06-30 23:48:58   2024-07-01 00:28:04              1.0
# 2         2  2024-07-01 00:23:18   2024-07-01 00:29:51              1.0
# 3         1  2024-07-01 00:10:33   2024-07-01 00:27:31              0.0
# 4         1  2024-07-01 00:07:55   2024-07-01 00:34:34              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           3.20         1.0                  N           140            79
# 1          19.48         2.0                  N           132           113
# 2           1.18         1.0                  N           237           145
# 3           9.10         1.0                  N           138           164
# 4          17.70         2.0                  N           132           263
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...
